# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from glob import glob
import seaborn as sns
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils import resample
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
from keras.optimizers import Adam
import pickle

# %%
# Initializing the path of the working directory
base_dir = r"C:\Users\MSI\Documents\MiniProject"

# Mapping the image id with their path so that it can be referred easily
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x 
                     for x in glob(os.path.join(base_dir, 'sample', '*.jpg'))}

# This dictionary is useful for displaying more human-friendly labels later on
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

print(imageid_path_dict)
# Out:
# {'ISIC_0024306': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024306.jpg', 'ISIC_0024307': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024307.jpg', 'ISIC_0024308': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024308.jpg', 'ISIC_0024309': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024309.jpg', 'ISIC_0024310': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024310.jpg', 'ISIC_0024311': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024311.jpg', 'ISIC_0024312': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024312.jpg', 'ISIC_0024313': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024313.jpg', 'ISIC_0024314': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024314.jpg', 'ISIC_0024315': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024315.jpg', 'ISIC_0024316': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024316.jpg', 'ISIC_0024317': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024317.jpg', 'ISIC_0024318': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024318.jpg', 'ISIC_0024319': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024319.jpg', 'ISIC_0024320': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024320.jpg', 'ISIC_0024321': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024321.jpg', 'ISIC_0024322': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024322.jpg', 'ISIC_0024323': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024323.jpg', 'ISIC_0024324': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024324.jpg', 'ISIC_0024325': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024325.jpg', 'ISIC_0024326': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024326.jpg', 'ISIC_0024327': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024327.jpg', 'ISIC_0024328': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024328.jpg', 'ISIC_0024329': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024329.jpg', 'ISIC_0024330': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024330.jpg', 'ISIC_0024331': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024331.jpg', 'ISIC_0024332': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024332.jpg', 'ISIC_0024333': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024333.jpg', 'ISIC_0024334': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024334.jpg', 'ISIC_0024335': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024335.jpg', 'ISIC_0024336': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024336.jpg', 'ISIC_0024337': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024337.jpg', 'ISIC_0024338': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024338.jpg', 'ISIC_0024339': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024339.jpg', 'ISIC_0024340': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024340.jpg', 'ISIC_0024341': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024341.jpg', 'ISIC_0024342': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024342.jpg', 'ISIC_0024343': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024343.jpg', 'ISIC_0024344': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024344.jpg', 'ISIC_0024345': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024345.jpg', 'ISIC_0024346': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024346.jpg', 'ISIC_0024347': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024347.jpg', 'ISIC_0024348': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024348.jpg', 'ISIC_0024349': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024349.jpg', 'ISIC_0024350': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024350.jpg', 'ISIC_0024351': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024351.jpg', 'ISIC_0024352': 'C:\\Users\\MSI\\Documents\\MiniProject\\sample\\ISIC_0024352.jpg', 'ISIC_0024353': 'C:\\Users\\MSI\\Documents\\MiniPro ...

# %%
# Reffering to the medadata having the information about all the images we have.
skin_df = pd.read_csv(os.path.join(base_dir, 'HAM10000_metadata.csv'))

# Creating New Columns path , cell_type and cell_type_idx for better readability

# Keeping the path of the respected image
skin_df['path'] = skin_df['image_id'].map(imageid_path_dict.get)

# Keeping the human understable Name with the respected name
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get)

# Keeping the index of the cell_type of the dict
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes

# %%
skin_df['cell_type'].value_counts()
# Out:
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: cell_type, dtype: int64

# %%
skin_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset                                               path  \
# 0  vidir_modern  C:\Users\MSI\Documents\MiniProject\sample\ISIC...
# 1  vidir_modern  C:\Users\MSI\Documents\MiniProject\sample\ISIC...
# 2  vidir_modern  C:\Users\MSI\Documents\MiniProject\sample\ISIC...
# 3  vidir_modern  C:\Users\MSI\Documents\MiniProject\sample\ISIC...
# 4  vidir_modern  C:\Users\MSI\Documents\MiniProject\sample\ISIC...
#
#                         cell_type  cell_type_idx
# 0  Benign keratosis-like lesions               2
# 1  Benign keratosis-like lesions               2
# 2  Benign keratosis-like lesions               2
# 3  Benign keratosis-like lesions               2
# 4  Benign keratosis-like lesions               2

# %%
skin_df.isnull().sum()
# Out:
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age              57
# sex               0
# localization      0
# dataset           0
# path              0
# cell_type         0
# cell_type_idx     0
# dtype: int64

# %%
skin_df['age'].fillna((skin_df['age'].mean()) , inplace = True)

# %%
skin_df.isnull().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age              0
# sex              0
# localization     0
# dataset          0
# path             0
# cell_type        0
# cell_type_idx    0
# dtype: int64

# %%
cell_type_idx = 'cell_type_idx'
record_0 = skin_df[skin_df[cell_type_idx] == 0]
record_1 = skin_df[skin_df[cell_type_idx] == 1]
record_2 = skin_df[skin_df[cell_type_idx] == 2]
record_3 = skin_df[skin_df[cell_type_idx] == 3]
record_4 = skin_df[skin_df[cell_type_idx] == 4]
record_5 = skin_df[skin_df[cell_type_idx] == 5]
record_6 = skin_df[skin_df[cell_type_idx] == 6]

# %%
n = 500
record_bal_0 = resample(record_0 , replace = True , n_samples = n , random_state = 42)
record_bal_1 = resample(record_1 , replace = True , n_samples = n , random_state = 42)
record_bal_2 = resample(record_2 , replace = True , n_samples = n , random_state = 42)
record_bal_3 = resample(record_3 , replace = True , n_samples = n , random_state = 42)
record_bal_4 = resample(record_4 , replace = True , n_samples = n , random_state = 42)
record_bal_5 = resample(record_5 , replace = True , n_samples = n , random_state = 42)
record_bal_6 = resample(record_6 , replace = True , n_samples = n , random_state = 42)

# %%
balance_record = pd.concat([record_bal_0 , record_bal_1 , record_bal_2 , record_bal_3 , record_bal_4 , record_bal_5 , record_bal_6])

# %%
balance_record['image'] = balance_record['path'].map(lambda x: np.asarray(Image.open(x).resize((64,64))))

# %%
X = np.asarray(balance_record['image'].tolist())

# %%
Y = balance_record['cell_type_idx']

# %%
Y_cat = to_categorical(Y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y_cat, test_size=0.20,random_state=42)

# %%
x_train_mean = np.mean(x_train)
x_test_mean = np.mean(x_test)

x_train_std = np.std(x_train)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean) / x_train_std
x_test = (x_test - x_test_mean) / x_test_std

# %%
input_shape = (64 , 64 , 3)

model = Sequential()
model.add(Conv2D(256, kernel_size=(3, 3),activation='relu',padding = 'Same',input_shape=input_shape))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, kernel_size=(3, 3),activation='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(64, kernel_size=(3, 3),activation='relu'))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())

model.add(Dense(32, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 256)       7168
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 256)      0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 256)       0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 128)       295040
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 15, 15, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 64)        73792
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 32)                73760
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 449,991
# Trainable params: 449,991
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam' , loss='categorical_crossentropy' , metrics=['accuracy'])

# %%
epochs = 100
batch_size = 16
history = model.fit(x_train , y_train , epochs = epochs , batch_size = batch_size , validation_data=(x_test , y_test) , verbose = 1)
# Out:
# Epoch 1/100
# 175/175 [==============================] - 94s 530ms/step - loss: 1.7272 - accuracy: 0.2896 - val_loss: 1.6225 - val_accuracy: 0.3643
# Epoch 2/100
# 175/175 [==============================] - 80s 455ms/step - loss: 1.4590 - accuracy: 0.4289 - val_loss: 1.4205 - val_accuracy: 0.4714
# Epoch 3/100
# 175/175 [==============================] - 79s 454ms/step - loss: 1.3276 - accuracy: 0.4846 - val_loss: 1.2321 - val_accuracy: 0.5400
# Epoch 4/100
# 175/175 [==============================] - 80s 458ms/step - loss: 1.1952 - accuracy: 0.5321 - val_loss: 1.1804 - val_accuracy: 0.5429
# Epoch 5/100
# 175/175 [==============================] - 76s 436ms/step - loss: 1.1113 - accuracy: 0.5636 - val_loss: 1.1336 - val_accuracy: 0.5800
# Epoch 6/100
# 175/175 [==============================] - 74s 424ms/step - loss: 0.9883 - accuracy: 0.6171 - val_loss: 1.0440 - val_accuracy: 0.5914
# Epoch 7/100
# 175/175 [==============================] - 73s 420ms/step - loss: 0.9315 - accuracy: 0.6486 - val_loss: 0.9643 - val_accuracy: 0.6457
# Epoch 8/100
# 175/175 [==============================] - 74s 422ms/step - loss: 0.8340 - accuracy: 0.7021 - val_loss: 0.8618 - val_accuracy: 0.6829
# Epoch 9/100
# 175/175 [==============================] - 73s 418ms/step - loss: 0.7648 - accuracy: 0.7182 - val_loss: 0.8686 - val_accuracy: 0.6929
# Epoch 10/100
# 175/175 [==============================] - 74s 420ms/step - loss: 0.6782 - accuracy: 0.7557 - val_loss: 0.7643 - val_accuracy: 0.7214
# Epoch 11/100
# 175/175 [==============================] - 73s 416ms/step - loss: 0.6210 - accuracy: 0.7689 - val_loss: 0.7960 - val_accuracy: 0.7286
# Epoch 12/100
# 175/175 [==============================] - 79s 454ms/step - loss: 0.5568 - accuracy: 0.8011 - val_loss: 0.8413 - val_accuracy: 0.7100
# Epoch 13/100
# 175/175 [==============================] - 77s 438ms/step - loss: 0.5349 - accuracy: 0.8029 - val_loss: 0.8038 - val_accuracy: 0.7586
# Epoch 14/100
# 175/175 [==============================] - 77s 440ms/step - loss: 0.4938 - accuracy: 0.8200 - val_loss: 0.7365 - val_accuracy: 0.7543
# Epoch 15/100
# 175/175 [==============================] - 77s 441ms/step - loss: 0.4682 - accuracy: 0.8271 - val_loss: 0.7612 - val_accuracy: 0.7586
# Epoch 16/100
# 175/175 [==============================] - 77s 440ms/step - loss: 0.4442 - accuracy: 0.8354 - val_loss: 0.7107 - val_accuracy: 0.7700
# Epoch 17/100
# 175/175 [==============================] - 73s 415ms/step - loss: 0.3916 - accuracy: 0.8496 - val_loss: 0.7246 - val_accuracy: 0.8014
# Epoch 18/100
# 175/175 [==============================] - 72s 414ms/step - loss: 0.4145 - accuracy: 0.8504 - val_loss: 0.8123 - val_accuracy: 0.7700
# Epoch 19/100
# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=1)
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
model.save("balance_model.h5")
# Out:
# 22/22 [==============================] - 5s 216ms/step - loss: 1.3236 - accuracy: 0.8286
# Test: accuracy = 0.828571  ;  loss = 1.323605

# %%
#1. Function to plot model's validation loss and validation accuracy
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1, len(model_history.history['accuracy'])/10))
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
   #  axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1, len(model_history.history['loss'])/10))

    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
plot_model_history(history)

# %%
prediction = model.predict(x_test)
# Out:
# 22/22 [==============================] - 5s 227ms/step

# %%
y_predict_classes = np.argmax(prediction , axis=1)

# %%
y_predict_classes
# Out:
# array([3, 4, 4, 3, 0, 5, 3, 3, 5, 0, 3, 5, 6, 5, 1, 4, 1, 0, 6, 5, 0, 3,
#        5, 3, 2, 5, 1, 1, 3, 6, 6, 3, 5, 1, 6, 6, 0, 0, 1, 4, 3, 6, 1, 4,
#        4, 0, 3, 3, 1, 2, 0, 4, 5, 6, 2, 0, 5, 0, 4, 3, 6, 5, 1, 0, 3, 6,
#        0, 3, 5, 5, 2, 1, 2, 2, 1, 4, 6, 5, 6, 3, 6, 6, 6, 6, 5, 5, 2, 0,
#        1, 0, 2, 6, 1, 5, 6, 5, 0, 5, 3, 1, 0, 4, 2, 2, 2, 0, 6, 6, 1, 0,
#        0, 1, 0, 2, 4, 1, 6, 2, 2, 3, 1, 2, 6, 2, 1, 1, 4, 3, 1, 0, 3, 0,
#        0, 6, 5, 4, 6, 6, 1, 3, 2, 6, 4, 3, 5, 5, 5, 1, 4, 0, 0, 4, 4, 1,
#        5, 2, 0, 3, 5, 3, 5, 5, 4, 4, 2, 1, 2, 0, 4, 3, 3, 2, 0, 2, 3, 6,
#        1, 5, 1, 6, 6, 2, 2, 0, 2, 2, 2, 3, 3, 5, 4, 5, 6, 2, 4, 6, 2, 3,
#        2, 0, 2, 0, 3, 5, 0, 5, 5, 6, 6, 4, 4, 0, 6, 6, 6, 6, 2, 4, 0, 4,
#        2, 1, 0, 1, 5, 3, 6, 2, 3, 3, 2, 3, 1, 6, 1, 3, 2, 3, 0, 1, 1, 0,
#        1, 0, 3, 3, 4, 1, 6, 3, 2, 6, 3, 0, 1, 3, 1, 2, 1, 3, 2, 0, 5, 2,
#        6, 4, 1, 4, 0, 1, 6, 3, 0, 1, 0, 0, 0, 6, 5, 3, 2, 3, 0, 6, 0, 1,
#        0, 4, 1, 6, 5, 1, 3, 4, 4, 5, 5, 1, 2, 3, 0, 0, 1, 6, 2, 1, 5, 3,
#        1, 5, 6, 6, 2, 0, 1, 6, 4, 1, 2, 0, 5, 6, 2, 4, 5, 0, 0, 3, 1, 1,
#        4, 1, 6, 4, 4, 5, 0, 2, 2, 1, 3, 0, 3, 2, 2, 0, 4, 3, 4, 2, 3, 6,
#        0, 3, 6, 4, 3, 4, 2, 3, 3, 1, 2, 0, 5, 6, 0, 1, 0, 2, 2, 6, 2, 3,
#        2, 5, 0, 0, 5, 3, 2, 0, 5, 3, 4, 2, 0, 4, 2, 2, 0, 2, 4, 4, 0, 2,
#        2, 4, 0, 0, 2, 5, 0, 3, 5, 3, 4, 5, 1, 3, 1, 4, 3, 2, 4, 2, 5, 0,
#        3, 1, 6, 6, 6, 6, 0, 2, 2, 4, 6, 2, 3, 5, 5, 0, 2, 0, 6, 1, 2, 0,
#        2, 4, 0, 2, 1, 5, 5, 3, 6, 6, 0, 3, 2, 1, 4, 6, 6, 2, 4, 5, 1, 0,
#        6, 2, 5, 0, 5, 0, 3, 6, 3, 5, 6, 6, 1, 0, 0, 2, 1, 2, 4, 1, 5, 6,
#        3, 3, 2, 4, 3, 0, 4, 1, 0, 2, 4, 3, 3, 5, 3, 2, 2, 0, 2, 2, 6, 1,
#        2, 3, 3, 0, 0, 3, 2, 4, 2, 1, 0, 0, 5, 5, 2, 3, 4, 1, 4, 0, 3, 5,
#        5, 2, 6, 6, 1, 0, 6, 2, 1, 0, 2, 0, 5, 4, 3, 0, 3, 4, 4, 2, 2, 0,
#        1, 2, 3, 5, 6, 3, 5, 1, 2, 3, 2, 2, 3, 5, 2, 5, 0, 3, 6, 0, 3, 3,
#        1, 5, 5, 1, 3, 1, 6, 2, 4, 3, 3, 6, 0, 6, 1, 0, 3, 5, 6, 4, 2, 3,
#        6, 2, 5, 2, 0, 1, 2, 1, 3, 0, 4, 1, 4, 2, 6, 4, 3, 0, 2, 1, 3, 6,
#        2, 0, 6, 5, 0, 3, 6, 0, 5, 3, 5, 5, 6, 6, 1, 5, 5, 4, 6, 2, 6, 4,
#        6, 4, 1, 1, 2, 0, 2, 3, 6, 6, 1, 5, 2, 5, 4, 4, 5, 0, 1, 0, 5, 4,
#        0, 2, 1, 2, 2, 6, 6, 2, 3, 5, 0, 3, 1, 5, 4, 1, 3, 2, 3, 5, 1, 2,
#        5, 2, 0, 0, 6, 5, 5, 4, 2, 1, 4, 2, 4, 6, 1, 1, 3, 4], dtype=int64)

# %%
y_true = np.argmax(y_test , axis=1)

# %%
y_true
# Out:
# array([3, 4, 4, 3, 0, 4, 3, 3, 2, 0, 3, 5, 6, 1, 1, 1, 1, 2, 6, 5, 0, 3,
#        0, 3, 2, 2, 1, 0, 3, 6, 6, 3, 4, 1, 6, 6, 0, 0, 1, 4, 3, 6, 1, 4,
#        4, 0, 3, 3, 1, 0, 0, 0, 5, 6, 2, 0, 2, 0, 4, 3, 6, 2, 1, 0, 3, 6,
#        0, 3, 1, 5, 5, 1, 0, 2, 1, 4, 6, 5, 6, 3, 6, 6, 6, 6, 5, 5, 2, 5,
#        0, 0, 4, 6, 1, 5, 6, 5, 0, 2, 3, 1, 0, 4, 2, 2, 0, 0, 6, 6, 1, 0,
#        0, 1, 2, 1, 4, 1, 6, 1, 5, 3, 1, 5, 6, 2, 1, 1, 4, 3, 1, 0, 3, 0,
#        0, 6, 4, 4, 6, 6, 1, 0, 2, 6, 4, 3, 5, 5, 4, 1, 2, 0, 0, 4, 4, 1,
#        5, 2, 0, 3, 0, 3, 5, 5, 0, 5, 2, 1, 2, 4, 4, 3, 3, 1, 0, 2, 3, 6,
#        1, 5, 1, 6, 6, 2, 0, 0, 2, 1, 2, 3, 3, 5, 4, 5, 6, 2, 4, 6, 4, 3,
